# %%
import sys
sys.path.append("..")
sys.path.append("../..")

from modules.config import (
    check_password,
    load_configurations,
    load_toml_config,
    page_config,
    data_URL,
    firebase_credentials,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 sys.path.append("..")
#       3 sys.path.append("../..")
# ----> 5 from modules.config import (
#       6     check_password,
#       7     load_configurations,
#       8     load_toml_config,
#       9     page_config,
#      10     data_URL,
#      11     firebase_credentials,
#      12 )
#
# File ~/Documents/GardyL/Dev_projects/_Github_repositories/app_team_picker/tests/../modules/config.py:7
#       5 import numpy as np
#       6 import toml
# ----> 7 from dotenv import find_dotenv, load_dotenv
#      10 def check_password(st) -> bool:
#      11     """Returns `True` if the user had the correct password."""
#
# ModuleNotFoundError: No module named 'dotenv'
